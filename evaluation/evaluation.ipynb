# %%
# !hf auth login

# %% [markdown]
# ## HumanEvalX

# %% [markdown]
# ### Llama-3-8B

# %%
# !bash ./humaneval/sample_scripts/llama-3-8b.sh

# %% [markdown]
# ## CoNaLa

# %% [markdown]
# ### Llama-3-8B

# %%
# !bash ./conala/sample_scripts/llama-3-8b.sh

# %% [markdown]
# ## APPS

# %% [markdown]
# ### Llama-3-8B

# %%
# !bash ./apps/sample_scripts/llama-3-8b.sh

# %% [markdown]
# ## BigCodeBench

# %% [markdown]
# ### Llama-3-8B

# %%
# !bash ./bigcodebench/sample_scripts/llama-3-8b.sh
